# %%
## import library
import pandas as pd

# %%
## import CSV file of deaths in largest NC jails
deaths = pd.read_csv("NorthCarolina_deaths.csv")

# %%
deaths.head()
# Out:
#       id state    county                                jail    year  \
# 0  326.0    NC  Buncombe  Buncombe County Detention Facility  2008.0
# 1  326.0    NC  Buncombe  Buncombe County Detention Facility  2008.0
# 2  326.0    NC  Buncombe  Buncombe County Detention Facility  2009.0
# 3  326.0    NC  Buncombe  Buncombe County Detention Facility  2010.0
# 4  326.0    NC  Buncombe  Buncombe County Detention Facility  2010.0
#
#   date_of_death  full_name last_name first_name mid_name  ... cause_short  \
# 0     3/10/2008        NaN   McMahan     Tommy       NaN  ...           M
# 1    12/16/2008        NaN    Austin       Thad      NaN  ...           S
# 2      3/3/2009        NaN  Chandler    Brandon      NaN  ...           S
# 3     2/20/2010        NaN      Aidt    Michael      NaN  ...           S
# 4      5/7/2010        NaN    Huskey      David      NaN  ...           S
#
#         cause_detail        dob yob   age  race  race_detail gender  \
# ...

# %%
## import CSV file of largest NC jails
jails = pd.read_csv("NorthCarolina_jails_edit.csv")

# %%
jails
# Out:
#      id   fips statecode           state  state_notes       county  \
# 0   326  37021        NC  North Carolina          NaN     Buncombe
# 1   327  37051        NC  North Carolina          NaN   Cumberland
# 2   328  37063        NC  North Carolina          NaN       Durham
# 3   329  37067        NC  North Carolina          NaN      Forsyth
# 4   330  37071        NC  North Carolina          NaN       Gaston
# 5   331  37081        NC  North Carolina          NaN     Guilford
# 6   522  37081        NC  North Carolina          NaN     Guilford
# 7   332  37119        NC  North Carolina          NaN  Mecklenburg
# 8   523  37119        NC  North Carolina          NaN  Mecklenburg
# 9   335  37129        NC  North Carolina          NaN  New Hanover
# 10  333  37147        NC  North Carolina          NaN         Pitt
# 11  334  37183        NC  North Carolina          NaN         Wake
#
#                                                  jail  \
# ...

# %%
##create a subset of jails in 2008 whose healthcare provider was Wellpath

wellpath08 = jails[jails["med2008"] == "Wellpath"]

# %%
##create a subset of jails in 2009 whose healthcare provider was Wellpath
wellpath09 = jails[jails["med2009"] == "Wellpath"]

# %%
wellpath10 = jails[jails["med2010"] == "Wellpath"]
wellpath10
# Out:
#     id   fips statecode           state  state_notes       county  \
# 2  328  37063        NC  North Carolina          NaN       Durham
# 3  329  37067        NC  North Carolina          NaN      Forsyth
# 7  332  37119        NC  North Carolina          NaN  Mecklenburg
# 8  523  37119        NC  North Carolina          NaN  Mecklenburg
# 9  335  37129        NC  North Carolina          NaN  New Hanover
#
#                               jail                            jail_notes  \
# 2               Durham County Jail                                   NaN
# 3  Forsyth County Detention Center                                   NaN
# 7  Mecklenburg County Jail Central                                   NaN
# 8    Mecklenburg County Jail North                                   NaN
# 9   New Hanover Detention Facility  2009 ADP averaged from 2010 and 2011
#
#    d2008  d2009  ...   med2010   med2011   med2012   med2013   med2014  \
# ...

# %%
wellpath11 = jails[jails["med2011"] == "Wellpath"]
wellpath11
# Out:
#     id   fips statecode           state  state_notes       county  \
# 2  328  37063        NC  North Carolina          NaN       Durham
# 3  329  37067        NC  North Carolina          NaN      Forsyth
# 7  332  37119        NC  North Carolina          NaN  Mecklenburg
# 8  523  37119        NC  North Carolina          NaN  Mecklenburg
# 9  335  37129        NC  North Carolina          NaN  New Hanover
#
#                               jail                            jail_notes  \
# 2               Durham County Jail                                   NaN
# 3  Forsyth County Detention Center                                   NaN
# 7  Mecklenburg County Jail Central                                   NaN
# 8    Mecklenburg County Jail North                                   NaN
# 9   New Hanover Detention Facility  2009 ADP averaged from 2010 and 2011
#
#    d2008  d2009  ...   med2010   med2011   med2012   med2013   med2014  \
# ...

# %%
wellpath12 = jails[jails["med2012"] == "Wellpath"]
wellpath12
# Out:
#     id   fips statecode           state  state_notes       county  \
# 2  328  37063        NC  North Carolina          NaN       Durham
# 3  329  37067        NC  North Carolina          NaN      Forsyth
# 7  332  37119        NC  North Carolina          NaN  Mecklenburg
# 8  523  37119        NC  North Carolina          NaN  Mecklenburg
# 9  335  37129        NC  North Carolina          NaN  New Hanover
#
#                               jail                            jail_notes  \
# 2               Durham County Jail                                   NaN
# 3  Forsyth County Detention Center                                   NaN
# 7  Mecklenburg County Jail Central                                   NaN
# 8    Mecklenburg County Jail North                                   NaN
# 9   New Hanover Detention Facility  2009 ADP averaged from 2010 and 2011
#
#    d2008  d2009  ...   med2010   med2011   med2012   med2013   med2014  \
# ...

# %%
wellpath13 = jails[jails["med2013"] == "Wellpath"]
wellpath13
# Out:
#     id   fips statecode           state  state_notes       county  \
# 2  328  37063        NC  North Carolina          NaN       Durham
# 3  329  37067        NC  North Carolina          NaN      Forsyth
# 7  332  37119        NC  North Carolina          NaN  Mecklenburg
# 8  523  37119        NC  North Carolina          NaN  Mecklenburg
# 9  335  37129        NC  North Carolina          NaN  New Hanover
#
#                               jail                            jail_notes  \
# 2               Durham County Jail                                   NaN
# 3  Forsyth County Detention Center                                   NaN
# 7  Mecklenburg County Jail Central                                   NaN
# 8    Mecklenburg County Jail North                                   NaN
# 9   New Hanover Detention Facility  2009 ADP averaged from 2010 and 2011
#
#    d2008  d2009  ...   med2010   med2011   med2012   med2013   med2014  \
# ...

# %%
wellpath14 = jails[jails["med2014"] == "Wellpath"]
wellpath14
# Out:
#     id   fips statecode           state  state_notes       county  \
# 2  328  37063        NC  North Carolina          NaN       Durham
# 3  329  37067        NC  North Carolina          NaN      Forsyth
# 7  332  37119        NC  North Carolina          NaN  Mecklenburg
# 8  523  37119        NC  North Carolina          NaN  Mecklenburg
# 9  335  37129        NC  North Carolina          NaN  New Hanover
#
#                               jail                            jail_notes  \
# 2               Durham County Jail                                   NaN
# 3  Forsyth County Detention Center                                   NaN
# 7  Mecklenburg County Jail Central                                   NaN
# 8    Mecklenburg County Jail North                                   NaN
# 9   New Hanover Detention Facility  2009 ADP averaged from 2010 and 2011
#
#    d2008  d2009  ...   med2010   med2011   med2012   med2013   med2014  \
# ...

# %%
wellpath15 = jails[jails["med2015"] == "Wellpath"]
wellpath15
# Out:
#     id   fips statecode           state  state_notes       county  \
# 0  326  37021        NC  North Carolina          NaN     Buncombe
# 2  328  37063        NC  North Carolina          NaN       Durham
# 3  329  37067        NC  North Carolina          NaN      Forsyth
# 5  331  37081        NC  North Carolina          NaN     Guilford
# 6  522  37081        NC  North Carolina          NaN     Guilford
# 7  332  37119        NC  North Carolina          NaN  Mecklenburg
# 8  523  37119        NC  North Carolina          NaN  Mecklenburg
# 9  335  37129        NC  North Carolina          NaN  New Hanover
#
#                                  jail                            jail_notes  \
# 0  Buncombe County Detention Facility                                   NaN
# 2                  Durham County Jail                                   NaN
# 3     Forsyth County Detention Center                                   NaN
# ...

# %%
wellpath16 = jails[jails["med2016"] == "Wellpath"]
wellpath16
# Out:
#     id   fips statecode           state  state_notes       county  \
# 0  326  37021        NC  North Carolina          NaN     Buncombe
# 2  328  37063        NC  North Carolina          NaN       Durham
# 3  329  37067        NC  North Carolina          NaN      Forsyth
# 5  331  37081        NC  North Carolina          NaN     Guilford
# 6  522  37081        NC  North Carolina          NaN     Guilford
# 7  332  37119        NC  North Carolina          NaN  Mecklenburg
# 8  523  37119        NC  North Carolina          NaN  Mecklenburg
# 9  335  37129        NC  North Carolina          NaN  New Hanover
#
#                                  jail                            jail_notes  \
# 0  Buncombe County Detention Facility                                   NaN
# 2                  Durham County Jail                                   NaN
# 3     Forsyth County Detention Center                                   NaN
# ...

# %%
wellpath17 = jails[jails["med2017"] == "Wellpath"]
wellpath17
# Out:
#     id   fips statecode           state  state_notes       county  \
# 0  326  37021        NC  North Carolina          NaN     Buncombe
# 2  328  37063        NC  North Carolina          NaN       Durham
# 3  329  37067        NC  North Carolina          NaN      Forsyth
# 5  331  37081        NC  North Carolina          NaN     Guilford
# 6  522  37081        NC  North Carolina          NaN     Guilford
# 7  332  37119        NC  North Carolina          NaN  Mecklenburg
# 8  523  37119        NC  North Carolina          NaN  Mecklenburg
# 9  335  37129        NC  North Carolina          NaN  New Hanover
#
#                                  jail                            jail_notes  \
# 0  Buncombe County Detention Facility                                   NaN
# 2                  Durham County Jail                                   NaN
# 3     Forsyth County Detention Center                                   NaN
# ...

# %%
wellpath18 = jails[jails["med2018"] == "Wellpath"]
wellpath18
# Out:
#     id   fips statecode           state  state_notes       county  \
# 0  326  37021        NC  North Carolina          NaN     Buncombe
# 2  328  37063        NC  North Carolina          NaN       Durham
# 3  329  37067        NC  North Carolina          NaN      Forsyth
# 5  331  37081        NC  North Carolina          NaN     Guilford
# 6  522  37081        NC  North Carolina          NaN     Guilford
# 7  332  37119        NC  North Carolina          NaN  Mecklenburg
# 8  523  37119        NC  North Carolina          NaN  Mecklenburg
# 9  335  37129        NC  North Carolina          NaN  New Hanover
#
#                                  jail                            jail_notes  \
# 0  Buncombe County Detention Facility                                   NaN
# 2                  Durham County Jail                                   NaN
# 3     Forsyth County Detention Center                                   NaN
# ...

# %%
wellpath19 = jails[jails["med2019"] == "Wellpath"]
wellpath19
# Out:
#     id   fips statecode           state  state_notes       county  \
# 0  326  37021        NC  North Carolina          NaN     Buncombe
# 2  328  37063        NC  North Carolina          NaN       Durham
# 3  329  37067        NC  North Carolina          NaN      Forsyth
# 5  331  37081        NC  North Carolina          NaN     Guilford
# 6  522  37081        NC  North Carolina          NaN     Guilford
# 7  332  37119        NC  North Carolina          NaN  Mecklenburg
# 8  523  37119        NC  North Carolina          NaN  Mecklenburg
# 9  335  37129        NC  North Carolina          NaN  New Hanover
#
#                                  jail                            jail_notes  \
# 0  Buncombe County Detention Facility                                   NaN
# 2                  Durham County Jail                                   NaN
# 3     Forsyth County Detention Center                                   NaN
# ...

# %%
## sort healthcare providers by count by year
jailvalues08 = jails["med2008"].value_counts()
jailvalues08
# Out:
# public                               3
# Wellpath                             2
# Corizon Health                       2
# Corizon Health/Wellpath              2
# NaphCare, Inc.                       1
# Carolina Correctional Health         1
# Eastern Carolina Medical Services    1
# Name: med2008, dtype: int64

# %%
jailvalues09 = jails["med2009"].value_counts()
jailvalues09
# Out:
# Wellpath                             4
# public                               3
# Corizon Health                       2
# NaphCare, Inc./Wellpath              1
# Carolina Correctional Health         1
# Eastern Carolina Medical Services    1
# Name: med2009, dtype: int64

# %%
jailvalues10 = jails["med2010"].value_counts()
jailvalues10
# Out:
# Wellpath                             5
# public                               3
# Corizon Health                       2
# Carolina Correctional Health         1
# Eastern Carolina Medical Services    1
# Name: med2010, dtype: int64

# %%
jailvalues11 = jails["med2011"].value_counts()
jailvalues11
# Out:
# Wellpath                             5
# public                               3
# Corizon Health                       2
# Carolina Correctional Health         1
# Eastern Carolina Medical Services    1
# Name: med2011, dtype: int64

# %%
jailvalues12 = jails["med2012"].value_counts()
jailvalues12
# Out:
# Wellpath                             5
# public                               3
# Corizon Health                       2
# Carolina Correctional Health         1
# Eastern Carolina Medical Services    1
# Name: med2012, dtype: int64

# %%
jailvalues13 = jails["med2013"].value_counts()
jailvalues13
# Out:
# Wellpath                             5
# public                               3
# Corizon Health                       2
# Carolina Correctional Health         1
# Eastern Carolina Medical Services    1
# Name: med2013, dtype: int64

# %%
jailvalues14 = jails["med2014"].value_counts()
jailvalues14
# Out:
# Wellpath                             5
# public                               2
# Corizon Health/Wellpath              2
# Eastern Carolina Medical Services    1
# Carolina Correctional Health         1
# public/Wellpath                      1
# Name: med2014, dtype: int64

# %%
jailvalues15 = jails["med2015"].value_counts()
jailvalues15
# Out:
# Wellpath                             8
# public                               2
# Carolina Correctional Health         1
# Eastern Carolina Medical Services    1
# Name: med2015, dtype: int64

# %%
jailvalues16 = jails["med2016"].value_counts()
jailvalues16
# Out:
# Wellpath                             8
# public                               2
# Carolina Correctional Health         1
# Eastern Carolina Medical Services    1
# Name: med2016, dtype: int64

# %%
jailvalues17 = jails["med2017"].value_counts()
jailvalues17
# Out:
# Wellpath                             8
# public                               1
# Carolina Correctional Health         1
# public/Southern Health Partners      1
# Eastern Carolina Medical Services    1
# Name: med2017, dtype: int64

# %%
jailvalues18 = jails["med2018"].value_counts()
jailvalues18
# Out:
# Wellpath                             8
# Carolina Correctional Health         1
# Southern Health Partners             1
# public                               1
# Eastern Carolina Medical Services    1
# Name: med2018, dtype: int64

# %%
jailvalues19 = jails["med2019"].value_counts()
jailvalues19
# Out:
# Wellpath                             8
# Carolina Correctional Health         1
# Southern Health Partners             1
# public                               1
# Eastern Carolina Medical Services    1
# Name: med2019, dtype: int64

# %%
## How many incarcerated people each healthcare provider served each year and how did they die

# %%
pop08 = jails[["jail", "adp2008", "d2008", "su2008", "da2008", "il2008", "ho2008", "ac2008", "med2008"]]
pop08
# Out:
#                                                  jail  adp2008  d2008  su2008  \
# 0                  Buncombe County Detention Facility    427.0      2       1
# 1                              Cumberland County Jail    532.0      0       0
# 2                                  Durham County Jail    625.0      2       2
# 3                     Forsyth County Detention Center    881.0      3       0
# 4                            Gaston County Jail/Annex    542.0      0       0
# 5                         Greensboro Detention Center    519.0      0       0
# 6                         High Point Detention Center    341.0      0       0
# 7                     Mecklenburg County Jail Central   1842.0      2       0
# 8                       Mecklenburg County Jail North    676.0      0       0
# 9                      New Hanover Detention Facility      NaN      2       2
# 10                       Pitt County Detention Center    422.0      1       0
# ...

# %%
pop09 = jails[["jail", "adp2009", "d2009", "su2009", "da2009", "il2009", "ho2009", "ac2009", "med2009"]]
pop09
# Out:
#                                                  jail  adp2009  d2009  su2009  \
# 0                  Buncombe County Detention Facility    431.0      1       1
# 1                              Cumberland County Jail    550.0      0       0
# 2                                  Durham County Jail    582.0      0       0
# 3                     Forsyth County Detention Center    869.0      2       0
# 4                            Gaston County Jail/Annex    507.0      0       0
# 5                         Greensboro Detention Center    522.0      1       0
# 6                         High Point Detention Center    323.0      0       0
# 7                     Mecklenburg County Jail Central   1756.0      2       0
# 8                       Mecklenburg County Jail North    646.0      0       0
# 9                      New Hanover Detention Facility    495.0      0       0
# 10                       Pitt County Detention Center    449.5      0       0
# ...

# %%
pop10 = jails[["jail", "adp2010", "d2010", "su2010", "da2010", "il2010", "ho2010", "ac2010", "med2010"]]
pop10
# Out:
#                                                  jail  adp2010  d2010  su2010  \
# 0                  Buncombe County Detention Facility    396.0      2       2
# 1                              Cumberland County Jail    573.0      0       0
# 2                                  Durham County Jail    580.0      2       2
# 3                     Forsyth County Detention Center    824.0      1       0
# 4                            Gaston County Jail/Annex    505.0      1       0
# 5                         Greensboro Detention Center    528.0      1       0
# 6                         High Point Detention Center    345.0      0       0
# 7                     Mecklenburg County Jail Central   1530.0      1       0
# 8                       Mecklenburg County Jail North    526.0      1       0
# 9                      New Hanover Detention Facility    496.0      0       0
# 10                       Pitt County Detention Center    486.4      0       0
# ...

# %%
pop11 = jails[["jail", "adp2011", "d2011", "su2011", "da2011", "il2011", "ho2011", "ac2011", "med2011"]]
pop11
# Out:
#                                                  jail  adp2011  d2011  su2011  \
# 0                  Buncombe County Detention Facility    394.0      1       0
# 1                              Cumberland County Jail    586.0      0       0
# 2                                  Durham County Jail    530.0      1       1
# 3                     Forsyth County Detention Center    675.0      3       0
# 4                            Gaston County Jail/Annex    512.0      1       1
# 5                         Greensboro Detention Center    515.0      0       0
# 6                         High Point Detention Center    308.0      0       0
# 7                     Mecklenburg County Jail Central   1435.0      0       0
# 8                       Mecklenburg County Jail North    499.0      0       0
# 9                      New Hanover Detention Facility    494.0      0       0
# 10                       Pitt County Detention Center    500.5      1       0
# ...

# %%
pop12 = jails[["jail", "adp2012", "d2012", "su2012", "da2012", "il2012", "ho2012", "ac2012", "med2012"]]
pop12
# Out:
#                                                  jail  adp2012  d2012  su2012  \
# 0                  Buncombe County Detention Facility      424      0       0
# 1                              Cumberland County Jail      616      0       0
# 2                                  Durham County Jail      747      1       1
# 3                     Forsyth County Detention Center      775      1       0
# 4                            Gaston County Jail/Annex      515      0       0
# 5                         Greensboro Detention Center      533      0       0
# 6                         High Point Detention Center      299      0       0
# 7                     Mecklenburg County Jail Central     1395      2       0
# 8                       Mecklenburg County Jail North      487      0       0
# 9                      New Hanover Detention Facility      569      2       1
# 10                       Pitt County Detention Center      509      1       0
# ...

# %%
pop13 = jails[["jail", "adp2013", "d2013", "su2013", "da2013", "il2013", "ho2013", "ac2013", "med2013"]]
pop13
# Out:
#                                                  jail  adp2013  d2013  su2013  \
# 0                  Buncombe County Detention Facility   459.00      0       0
# 1                              Cumberland County Jail   678.00      0       0
# 2                                  Durham County Jail   560.00      1       1
# 3                     Forsyth County Detention Center   695.00      1       0
# 4                            Gaston County Jail/Annex   493.00      0       0
# 5                         Greensboro Detention Center   624.00      1       0
# 6                         High Point Detention Center   262.00      0       0
# 7                     Mecklenburg County Jail Central  1430.00      0       0
# 8                       Mecklenburg County Jail North   580.00      0       0
# 9                      New Hanover Detention Facility   567.00      0       0
# 10                       Pitt County Detention Center   488.25      1       0
# ...

# %%
pop14 = jails[["jail", "adp2014", "d2014", "su2014", "da2014", "il2014", "ho2014", "ac2014", "med2014"]]
pop14
# Out:
#                                                  jail  adp2014  d2014  su2014  \
# 0                  Buncombe County Detention Facility   443.00      1       1
# 1                              Cumberland County Jail   745.00      0       0
# 2                                  Durham County Jail   514.00      0       0
# 3                     Forsyth County Detention Center   761.00      0       0
# 4                            Gaston County Jail/Annex   508.00      0       0
# 5                         Greensboro Detention Center   680.00      1       0
# 6                         High Point Detention Center   287.00      0       0
# 7                     Mecklenburg County Jail Central  1299.00      2       1
# 8                       Mecklenburg County Jail North   555.00      0       0
# 9                      New Hanover Detention Facility   553.00      1       0
# 10                       Pitt County Detention Center   490.98      0       0
# ...

# %%
pop15 = jails[["jail", "adp2015", "d2015", "su2015", "da2015", "il2015", "ho2015", "ac2015", "med2015"]]
pop15
# Out:
#                                                  jail  adp2015  d2015  su2015  \
# 0                  Buncombe County Detention Facility   423.00      0       0
# 1                              Cumberland County Jail   723.00      0       0
# 2                                  Durham County Jail   510.00      2       0
# 3                     Forsyth County Detention Center   731.00      1       1
# 4                            Gaston County Jail/Annex   489.00      1       1
# 5                         Greensboro Detention Center   603.00      4       1
# 6                         High Point Detention Center   222.00      0       0
# 7                     Mecklenburg County Jail Central  1078.00      1       1
# 8                       Mecklenburg County Jail North   405.00      0       0
# 9                      New Hanover Detention Facility   562.00      0       0
# 10                       Pitt County Detention Center   471.75      1       0
# ...

# %%
pop16 = jails[["jail", "adp2016", "d2016", "su2016", "da2016", "il2016", "ho2016", "ac2016", "med2016"]]
pop16
# Out:
#                                                  jail  adp2016  d2016  su2016  \
# 0                  Buncombe County Detention Facility   478.00      0     0.0
# 1                              Cumberland County Jail   745.00      0     0.0
# 2                                  Durham County Jail   475.00      1     0.0
# 3                     Forsyth County Detention Center   683.00      0     0.0
# 4                            Gaston County Jail/Annex   525.00      2     2.0
# 5                         Greensboro Detention Center   570.00      0     0.0
# 6                         High Point Detention Center   249.00      0     0.0
# 7                     Mecklenburg County Jail Central  1197.00      1     1.0
# 8                       Mecklenburg County Jail North   247.00      0     0.0
# 9                      New Hanover Detention Facility   548.00      0     0.0
# 10                       Pitt County Detention Center   434.86      1     0.0
# ...

# %%
pop17 = jails[["jail", "adp2017", "d2017", "su2017", "da2017", "il2017", "ho2017", "ac2017", "med2017"]]
pop17
# Out:
#                                                  jail  adp2017  d2017  su2017  \
# 0                  Buncombe County Detention Facility   530.00      3       0
# 1                              Cumberland County Jail   753.00      0       0
# 2                                  Durham County Jail   489.00      2       1
# 3                     Forsyth County Detention Center   708.00      2       0
# 4                            Gaston County Jail/Annex   609.00      0       0
# 5                         Greensboro Detention Center   645.00      1       0
# 6                         High Point Detention Center   275.00      0       0
# 7                     Mecklenburg County Jail Central  1367.00      1       0
# 8                       Mecklenburg County Jail North   158.00      0       0
# 9                      New Hanover Detention Facility   584.00      0       0
# 10                       Pitt County Detention Center   440.53      0       0
# ...

# %%
pop18 = jails[["jail", "adp2018", "d2018", "su2018", "da2018", "il2018", "ho2018", "ac2018", "med2018"]]
pop18
# Out:
#                                                  jail  adp2018  d2018  su2018  \
# 0                  Buncombe County Detention Facility    529.5      0       0
# 1                              Cumberland County Jail    754.0      2       0
# 2                                  Durham County Jail    477.0      2       0
# 3                     Forsyth County Detention Center    768.0      2       1
# 4                            Gaston County Jail/Annex    635.0      0       0
# 5                         Greensboro Detention Center    657.0      3       0
# 6                         High Point Detention Center    252.0      1       0
# 7                     Mecklenburg County Jail Central   1304.0      4       2
# 8                       Mecklenburg County Jail North    254.0      1       1
# 9                      New Hanover Detention Facility    594.0      1       0
# 10                       Pitt County Detention Center    404.4      0       0
# ...

# %%
pop19 = jails[["jail", "adp2019", "d2019", "su2019", "da2019", "il2019", "ho2019", "ac2019", "med2019"]]
pop19
# Out:
#                                                  jail  adp2019  d2019  su2019  \
# 0                  Buncombe County Detention Facility   463.80      2       1
# 1                              Cumberland County Jail   737.00      3       0
# 2                                  Durham County Jail   393.00      0       0
# 3                     Forsyth County Detention Center   832.00      1       0
# 4                            Gaston County Jail/Annex   665.00      3       2
# 5                         Greensboro Detention Center   697.00      0       0
# 6                         High Point Detention Center   283.00      0       0
# 7                     Mecklenburg County Jail Central  1526.00      1       0
# 8                       Mecklenburg County Jail North   121.00      0       0
# 9                      New Hanover Detention Facility   541.00      1       0
# 10                       Pitt County Detention Center   459.68      0       0
# ...

# %%
pop08["il2008"].sum()
# Out:
# 7

# %%
jaildeath08 = pop08["d2008"].sum()

# %%
jailpop08 = pop08["adp2008"].sum()

# %%
## create filters to see jails with Wellpath-controlled healthcare
## create filters to see sum of jail population for Wellpath facilities each year wpop[year]
## create filters to see sum of deaths for Wellpath facilities each year wd[year]

# %%
mask08 = pop08["med2008"] == "Wellpath"
# Out:
# 2

# %%
df08 = pop08[mask08]
df08
# Out:
#                              jail  adp2008  d2008  su2008  da2008  il2008  \
# 2              Durham County Jail    625.0      2       2       0       0
# 9  New Hanover Detention Facility      NaN      2       2       0       0
#
#    ho2008  ac2008   med2008
# 2       0       0  Wellpath
# 9       0       0  Wellpath

# %%
wpop08 = df08["adp2008"].sum()
wpop08
# Out:
# 625.0

# %%
wd08 = df08["d2008"].sum()
wd08
# Out:
# 4

# %%
df08["su2008"].sum()
# Out:
# 4

# %%
mask09 = pop09["med2009"] == "Wellpath"
df09 = pop09[mask09]
df09
# Out:
#                               jail  adp2009  d2009  su2009  da2009  il2009  \
# 2               Durham County Jail    582.0      0       0       0       0
# 7  Mecklenburg County Jail Central   1756.0      2       0       0       2
# 8    Mecklenburg County Jail North    646.0      0       0       0       0
# 9   New Hanover Detention Facility    495.0      0       0       0       0
#
#    ho2009  ac2009   med2009
# 2       0       0  Wellpath
# 7       0       0  Wellpath
# 8       0       0  Wellpath
# 9       0       0  Wellpath

# %%
wpop09 = df09["adp2009"].sum()

# %%
wd09 = df09["d2009"].sum()
wd09
# Out:
# 2

# %%
mask10 = pop10["med2010"] == "Wellpath"
df10 = pop10[mask10]
df10
# Out:
#                               jail  adp2010  d2010  su2010  da2010  il2010  \
# 2               Durham County Jail    580.0      2       2       0       0
# 3  Forsyth County Detention Center    824.0      1       0       0       1
# 7  Mecklenburg County Jail Central   1530.0      1       0       0       1
# 8    Mecklenburg County Jail North    526.0      1       0       1       0
# 9   New Hanover Detention Facility    496.0      0       0       0       0
#
#    ho2010  ac2010   med2010
# 2       0       0  Wellpath
# 3       0       0  Wellpath
# 7       0       0  Wellpath
# 8       0       0  Wellpath
# 9       0       0  Wellpath

# %%
wpop10 = df10["adp2010"].sum()
wpop10
# Out:
# 3956.0

# %%
wd10 = df10["d2010"].sum()
wd10
# Out:
# 5

# %%
mask11 = pop11["med2011"] == "Wellpath"
df11 = pop11[mask11]
df11
# Out:
#                               jail  adp2011  d2011  su2011  da2011  il2011  \
# 2               Durham County Jail    530.0      1       1       0       0
# 3  Forsyth County Detention Center    675.0      3       0       0       3
# 7  Mecklenburg County Jail Central   1435.0      0       0       0       0
# 8    Mecklenburg County Jail North    499.0      0       0       0       0
# 9   New Hanover Detention Facility    494.0      0       0       0       0
#
#    ho2011  ac2011   med2011
# 2       0       0  Wellpath
# 3       0       0  Wellpath
# 7       0       0  Wellpath
# 8       0       0  Wellpath
# 9       0       0  Wellpath

# %%
wpop11 = df11["adp2011"].sum()
wpop11
# Out:
# 3633.0

# %%
wd11 = df11["d2011"].sum()
wd11
# Out:
# 4

# %%
mask12 = pop12["med2012"] == "Wellpath"
df12 = pop12[mask12]
df12
# Out:
#                               jail  adp2012  d2012  su2012  da2012  il2012  \
# 2               Durham County Jail      747      1       1       0       0
# 3  Forsyth County Detention Center      775      1       0       1       0
# 7  Mecklenburg County Jail Central     1395      2       0       0       2
# 8    Mecklenburg County Jail North      487      0       0       0       0
# 9   New Hanover Detention Facility      569      2       1       0       1
#
#    ho2012  ac2012   med2012
# 2       0       0  Wellpath
# 3       0       0  Wellpath
# 7       0       0  Wellpath
# 8       0       0  Wellpath
# 9       0       0  Wellpath

# %%
wpop12 = df12["adp2012"].sum()
wpop12
# Out:
# 3973

# %%
wd12 = df12["d2012"].sum()

wd12
# Out:
# 6

# %%
mask13 = pop13["med2013"] == "Wellpath"
df13 = pop13[mask13]
df13
# Out:
#                               jail  adp2013  d2013  su2013  da2013  il2013  \
# 2               Durham County Jail    560.0      1       1       0       0
# 3  Forsyth County Detention Center    695.0      1       0       0       1
# 7  Mecklenburg County Jail Central   1430.0      0       0       0       0
# 8    Mecklenburg County Jail North    580.0      0       0       0       0
# 9   New Hanover Detention Facility    567.0      0       0       0       0
#
#    ho2013  ac2013   med2013
# 2       0       0  Wellpath
# 3       0       0  Wellpath
# 7       0       0  Wellpath
# 8       0       0  Wellpath
# 9       0       0  Wellpath

# %%
wpop13 = df13["adp2013"].sum()
wpop13
# Out:
# 3832.0

# %%
wd13 = df13["d2013"].sum()
wd13
# Out:
# 2

# %%
mask14 = pop14["med2014"] == "Wellpath"
df14 = pop14[mask14]
df14
# Out:
#                               jail  adp2014  d2014  su2014  da2014  il2014  \
# 2               Durham County Jail    514.0      0       0       0       0
# 3  Forsyth County Detention Center    761.0      0       0       0       0
# 7  Mecklenburg County Jail Central   1299.0      2       1       0       1
# 8    Mecklenburg County Jail North    555.0      0       0       0       0
# 9   New Hanover Detention Facility    553.0      1       0       0       1
#
#    ho2014  ac2014   med2014
# 2       0       0  Wellpath
# 3       0       0  Wellpath
# 7       0       0  Wellpath
# 8       0       0  Wellpath
# 9       0       0  Wellpath

# %%
wpop14 = df14["adp2014"].sum()
wpop14
# Out:
# 3682.0

# %%
wd14 = df14["d2014"].sum()
wd14
# Out:
# 3

# %%
mask15 = pop15["med2015"] == "Wellpath"
df15 = pop15[mask15]
df15
# Out:
#                                  jail  adp2015  d2015  su2015  da2015  il2015  \
# 0  Buncombe County Detention Facility    423.0      0       0       0       0
# 2                  Durham County Jail    510.0      2       0       1       1
# 3     Forsyth County Detention Center    731.0      1       1       0       0
# 5         Greensboro Detention Center    603.0      4       1       0       3
# 6         High Point Detention Center    222.0      0       0       0       0
# 7     Mecklenburg County Jail Central   1078.0      1       1       0       0
# 8       Mecklenburg County Jail North    405.0      0       0       0       0
# 9      New Hanover Detention Facility    562.0      0       0       0       0
#
#    ho2015  ac2015   med2015
# 0       0       0  Wellpath
# 2       0       0  Wellpath
# 3       0       0  Wellpath
# 5       0       0  Wellpath
# 6       0       0  Wellpath
# 7       0       0  Wellpath
# 8       0       0  Wellpath
# 9       0       0  Wellpath

# %%
wpop15 = df15["adp2015"].sum()
wpop15
# Out:
# 4534.0

# %%
wd15 = df15["d2015"].sum()
wd15
# Out:
# 8

# %%
mask16 = pop16["med2016"] == "Wellpath"
df16 = pop16[mask16]
df16
# Out:
#                                  jail  adp2016  d2016  su2016  da2016  il2016  \
# 0  Buncombe County Detention Facility    478.0      0     0.0     0.0       0
# 2                  Durham County Jail    475.0      1     0.0     0.0       1
# 3     Forsyth County Detention Center    683.0      0     0.0     0.0       0
# 5         Greensboro Detention Center    570.0      0     0.0     0.0       0
# 6         High Point Detention Center    249.0      0     0.0     0.0       0
# 7     Mecklenburg County Jail Central   1197.0      1     1.0     0.0       0
# 8       Mecklenburg County Jail North    247.0      0     0.0     0.0       0
# 9      New Hanover Detention Facility    548.0      0     0.0     0.0       0
#
#    ho2016  ac2016   med2016
# 0     0.0     0.0  Wellpath
# 2     0.0     0.0  Wellpath
# 3     0.0     0.0  Wellpath
# 5     0.0     0.0  Wellpath
# 6     0.0     0.0  Wellpath
# 7     0.0     0.0  Wellpath
# 8     0.0     0.0  Wellpath
# 9     0.0     0.0  Wellpath

# %%
wpop16 = df16["adp2016"].sum()
wpop16
# Out:
# 4447.0

# %%
wd16 = df16["d2016"].sum()
wd16
# Out:
# 2

# %%
mask17 = pop17["med2017"] == "Wellpath"
df17 = pop17[mask17]
df17
# Out:
#                                  jail  adp2017  d2017  su2017  da2017  il2017  \
# 0  Buncombe County Detention Facility    530.0      3       0       2       1
# 2                  Durham County Jail    489.0      2       1       0       1
# 3     Forsyth County Detention Center    708.0      2       0       0       2
# 5         Greensboro Detention Center    645.0      1       0       0       1
# 6         High Point Detention Center    275.0      0       0       0       0
# 7     Mecklenburg County Jail Central   1367.0      1       0       0       1
# 8       Mecklenburg County Jail North    158.0      0       0       0       0
# 9      New Hanover Detention Facility    584.0      0       0       0       0
#
#    ho2017  ac2017   med2017
# 0       0       0  Wellpath
# 2       0       0  Wellpath
# 3       0       0  Wellpath
# 5       0       0  Wellpath
# 6       0       0  Wellpath
# 7       0       0  Wellpath
# 8       0       0  Wellpath
# 9       0       0  Wellpath

# %%
wpop17 = df17["adp2017"].sum()
wpop17
# Out:
# 4756.0

# %%
wd17 = df17["d2017"].sum()
wd17
# Out:
# 9

# %%
mask18 = pop18["med2018"] == "Wellpath"
df18 = pop18[mask18]
df18
# Out:
#                                  jail  adp2018  d2018  su2018  da2018  il2018  \
# 0  Buncombe County Detention Facility    529.5      0       0       0       0
# 2                  Durham County Jail    477.0      2       0       1       1
# 3     Forsyth County Detention Center    768.0      2       1       0       1
# 5         Greensboro Detention Center    657.0      3       0       0       3
# 6         High Point Detention Center    252.0      1       0       0       0
# 7     Mecklenburg County Jail Central   1304.0      4       2       2       0
# 8       Mecklenburg County Jail North    254.0      1       1       0       0
# 9      New Hanover Detention Facility    594.0      1       0       1       0
#
#    ho2018  ac2018   med2018
# 0       0       0  Wellpath
# 2       0       0  Wellpath
# 3       0       0  Wellpath
# 5       0       0  Wellpath
# 6       0       1  Wellpath
# 7       0       0  Wellpath
# 8       0       0  Wellpath
# 9       0       0  Wellpath

# %%
wpop18 = df18["adp2018"].sum()
wpop18
# Out:
# 4835.5

# %%
wd18 = df18["d2018"].sum()
wd18
# Out:
# 14

# %%
mask19 = pop19["med2019"] == "Wellpath"
df19 = pop19[mask19]
df19
# Out:
#                                  jail  adp2019  d2019  su2019  da2019  il2019  \
# 0  Buncombe County Detention Facility    463.8      2       1       0       1
# 2                  Durham County Jail    393.0      0       0       0       0
# 3     Forsyth County Detention Center    832.0      1       0       0       1
# 5         Greensboro Detention Center    697.0      0       0       0       0
# 6         High Point Detention Center    283.0      0       0       0       0
# 7     Mecklenburg County Jail Central   1526.0      1       0       1       0
# 8       Mecklenburg County Jail North    121.0      0       0       0       0
# 9      New Hanover Detention Facility    541.0      1       0       0       1
#
#    ho2019  ac2019   med2019
# 0       0       0  Wellpath
# 2       0       0  Wellpath
# 3       0       0  Wellpath
# 5       0       0  Wellpath
# 6       0       0  Wellpath
# 7       0       0  Wellpath
# 8       0       0  Wellpath
# 9       0       0  Wellpath

# %%
wpop19 = df19["adp2019"].sum()
wpop19
# Out:
# 4856.8

# %%
wd19 = df19["d2019"].sum()
wd19
# Out:
# 5

# %%
## Check total jail population by each year (sum of all jail pops)
## check total jail deaths each year
## check total jail illness related deaths each year
## tpop = total pop, dpop = death pop, ilpop = illness deaths population


tpop09 = pop09["adp2009"].sum()
tpop09
# Out:
# 8465.5

# %%
dpop09 = pop09["d2009"].sum()
dpop09
# Out:
# 7

# %%
ilpop09 = pop09["il2009"].sum()

# %%
tpop08 = pop08["adp2008"].sum()

# %%
dpop08 = pop08["d2008"].sum()

# %%
ilpop08 = pop08["il2008"].sum()

# %%
tpop10 = pop10["adp2010"].sum()

# %%
dpop10 = pop10["d2010"].sum()

# %%
ilpop10 = pop10["il2010"].sum()

# %%
tpop11 = pop11["adp2011"].sum()

# %%
dpop11 = pop11["d2011"].sum()

# %%
ilpop11 = pop11["il2011"].sum()

# %%
tpop12 = pop12["adp2012"].sum()

# %%
dpop12 = pop12["d2012"].sum()

# %%
ilpop12 = pop12["il2012"].sum()

# %%
tpop13 = pop13["adp2013"].sum()

# %%
dpop13 = pop13["d2013"].sum()

# %%
ilpop13 = pop13["il2013"].sum()

# %%
tpop14 = pop14["adp2014"].sum()

# %%
dpop14 = pop14["d2014"].sum()

# %%
ilpop14 = pop14["il2014"].sum()

# %%
tpop15 = pop15["adp2015"].sum()

# %%
dpop15 = pop15["d2015"].sum()

# %%
ilpop15 = pop15["il2015"].sum()

# %%
tpop16 = pop16["adp2016"].sum()

# %%
dpop16 = pop16["d2016"].sum()

# %%
ilpop16 = pop16["il2016"].sum()

# %%
tpop17 = pop17["adp2017"].sum()

# %%
dpop17 = pop17["d2017"].sum()

# %%
ilpop17 = pop17["il2017"].sum()

# %%
tpop18 = pop18["adp2018"].sum()

# %%
dpop18 = pop18["d2018"].sum()

# %%
ilpop18 = pop18["il2018"].sum()

# %%
tpop19 = pop19["adp2019"].sum()

# %%
dpop19 = pop19["d2019"].sum()

# %%
ilpop19 = pop19["il2019"].sum()

# %%
## Filter out public population 
## Filter out public deaths

# %%
filter08 = pop08["med2008"] == "public"
p08 = pop08[filter08]
p08
# Out:
#                                                  jail  adp2008  d2008  su2008  \
# 0                  Buncombe County Detention Facility    427.0      2       1
# 1                              Cumberland County Jail    532.0      0       0
# 11  Wake County Detention Centers (includes main d...   1327.0      0       0
#
#     da2008  il2008  ho2008  ac2008 med2008
# 0        0       1       0       0  public
# 1        0       0       0       0  public
# 11       0       0       0       0  public

# %%
ppop08 = p08["adp2008"].sum()
ppop08
# Out:
# 2286.0

# %%
pd08 = p08["d2008"].sum()
pd08
# Out:
# 2

# %%
filter09 = pop09["med2009"] == "public"
p09 = pop09[filter09]
p09
# Out:
#                                                  jail  adp2009  d2009  su2009  \
# 0                  Buncombe County Detention Facility    431.0      1       1
# 1                              Cumberland County Jail    550.0      0       0
# 11  Wake County Detention Centers (includes main d...   1335.0      1       0
#
#     da2009  il2009  ho2009  ac2009 med2009
# 0        0       0       0       0  public
# 1        0       0       0       0  public
# 11       0       1       0       0  public

# %%
ppop09 = p09["adp2009"].sum()
ppop09
# Out:
# 2316.0

# %%
pd09 = p09["d2009"].sum()
pd09
# Out:
# 2

# %%
filter10 = pop10["med2010"] == "public"
p10 = pop10[filter10]
p10
# Out:
#                                                  jail  adp2010  d2010  su2010  \
# 0                  Buncombe County Detention Facility    396.0      2       2
# 1                              Cumberland County Jail    573.0      0       0
# 11  Wake County Detention Centers (includes main d...   1353.0      2       2
#
#     da2010  il2010  ho2010  ac2010 med2010
# 0        0       0       0       0  public
# 1        0       0       0       0  public
# 11       0       0       0       0  public

# %%
ppop10 = p10["adp2010"].sum()
ppop10
# Out:
# 2322.0

# %%
pd10 = p10["d2010"].sum()
pd10
# Out:
# 4

# %%
filter11 = pop11["med2011"] == "public"
p11 = pop11[filter11]
p11
# Out:
#                                                  jail  adp2011  d2011  su2011  \
# 0                  Buncombe County Detention Facility    394.0      1       0
# 1                              Cumberland County Jail    586.0      0       0
# 11  Wake County Detention Centers (includes main d...   1192.0      2       1
#
#     da2011  il2011  ho2011  ac2011 med2011
# 0        0       1       0       0  public
# 1        0       0       0       0  public
# 11       0       1       0       0  public

# %%
ppop11 = p11["adp2011"].sum()
ppop11
# Out:
# 2172.0

# %%
pd11 = p11["d2011"].sum()
pd11
# Out:
# 3

# %%
filter12 = pop12["med2012"] == "public"
p12 = pop12[filter12]
p12
# Out:
#                                                  jail  adp2012  d2012  su2012  \
# 0                  Buncombe County Detention Facility      424      0       0
# 1                              Cumberland County Jail      616      0       0
# 11  Wake County Detention Centers (includes main d...     1263      1       0
#
#     da2012  il2012  ho2012  ac2012 med2012
# 0        0       0       0       0  public
# 1        0       0       0       0  public
# 11       0       1       0       0  public

# %%
ppop12 = p12["adp2012"].sum()
ppop12
# Out:
# 2303

# %%
pd12 = p12["d2012"].sum()
pd12
# Out:
# 1

# %%
filter13 = pop13["med2013"] == "public"
p13 = pop13[filter13]
p13
# Out:
#                                                  jail  adp2013  d2013  su2013  \
# 0                  Buncombe County Detention Facility    459.0      0       0
# 1                              Cumberland County Jail    678.0      0       0
# 11  Wake County Detention Centers (includes main d...   1308.0      1       0
#
#     da2013  il2013  ho2013  ac2013 med2013
# 0        0       0       0       0  public
# 1        0       0       0       0  public
# 11       0       1       0       0  public

# %%
ppop13 = p13["adp2013"].sum()
ppop13
# Out:
# 2445.0

# %%
pd13 = p13["d2013"].sum()
pd13
# Out:
# 1

# %%
filter14 = pop14["med2014"] == "public"
p14 = pop14[filter14]
p14
# Out:
#                                                  jail  adp2014  d2014  su2014  \
# 1                              Cumberland County Jail    745.0      0       0
# 11  Wake County Detention Centers (includes main d...   1234.0      3       1
#
#     da2014  il2014  ho2014  ac2014 med2014
# 1        0       0       0       0  public
# 11       0       2       0       0  public

# %%
ppop14 = p14["adp2014"].sum()
ppop14
# Out:
# 1979.0

# %%
pd14 = p14["d2014"].sum()
pd14
# Out:
# 3

# %%
filter15 = pop15["med2015"] == "public"
p15 = pop15[filter15]
p15
# Out:
#                                                  jail  adp2015  d2015  su2015  \
# 1                              Cumberland County Jail    723.0      0       0
# 11  Wake County Detention Centers (includes main d...   1140.0      2       1
#
#     da2015  il2015  ho2015  ac2015 med2015
# 1        0       0       0       0  public
# 11       1       0       0       0  public

# %%
ppop15 = p15["adp2015"].sum()
ppop15
# Out:
# 1863.0

# %%
pd15 = p15["d2015"].sum()
pd15
# Out:
# 2

# %%
filter16 = pop16["med2016"] == "public"
p16 = pop16[filter16]
p16
# Out:
#                                                  jail  adp2016  d2016  su2016  \
# 1                              Cumberland County Jail    745.0      0     0.0
# 11  Wake County Detention Centers (includes main d...   1168.0      2     NaN
#
#     da2016  il2016  ho2016  ac2016 med2016
# 1      0.0       0     0.0     0.0  public
# 11     NaN       1     NaN     NaN  public

# %%
ppop16 = p16["adp2016"].sum()
ppop16
# Out:
# 1913.0

# %%
pd16 = p16["d2016"].sum()
pd16
# Out:
# 2

# %%
filter17 = pop17["med2017"] == "public"
p17 = pop17[filter17]
p17
# Out:
#                                                  jail  adp2017  d2017  su2017  \
# 11  Wake County Detention Centers (includes main d...   1185.0      2       1
#
#     da2017  il2017  ho2017  ac2017 med2017
# 11       0       1       0       0  public

# %%
ppop17 = p17["adp2017"].sum()
ppop17
# Out:
# 1185.0

# %%
pd17 = p17["d2017"].sum()
pd17
# Out:
# 2

# %%
filter18 = pop18["med2018"] == "public"
p18 = pop18[filter18]
p18
# Out:
#                                                  jail  adp2018  d2018  su2018  \
# 11  Wake County Detention Centers (includes main d...   1210.0      2       1
#
#     da2018  il2018  ho2018  ac2018 med2018
# 11       0       1       0       0  public

# %%
ppop18 = p18["adp2018"].sum()
ppop18
# Out:
# 1210.0

# %%
pd18 = p18["d2018"].sum()
pd18
# Out:
# 2

# %%
filter19 = pop19["med2019"] == "public"
p19 = pop19[filter19]
p19
# Out:
#                                                  jail  adp2019  d2019  su2019  \
# 11  Wake County Detention Centers (includes main d...   1202.0      1       0
#
#     da2019  il2019  ho2019  ac2019 med2019
# 11       0       1       0       0  public

# %%
ppop19 = p19["adp2019"].sum()
ppop19
# Out:
# 1202.0

# %%
pd19 = p19["d2019"].sum()
pd19
# Out:
# 1

# %%
## Create a new dataframe called "newpop" with columns org by year: 
## total pop, total death pop, total wellpath pop, total wellpath death pop total, public pop, public death pop

# %%
year = [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]

# %%
totalpop = [tpop09, tpop10, tpop11, tpop12, tpop13, tpop14, tpop15, tpop16, tpop17, tpop18, tpop19]
totalpop
# Out:
# [8465.5,
#  8142.4,
#  7640.5,
#  8132,
#  8144.25,
#  8069.98,
#  7357.75,
#  7319.86,
#  7743.53,
#  7838.9,
#  7920.4800000000005]

# %%
totaldeaths = [dpop09, dpop10, dpop11, dpop12, dpop13, dpop14, dpop15, dpop16, dpop17, dpop18, dpop19]
totaldeaths
# Out:
# [7, 11, 9, 8, 5, 8, 12, 7, 11, 18, 12]

# %%
illnessdeaths = [ilpop09, ilpop10, ilpop11, ilpop12, ilpop13, ilpop14, ilpop15, ilpop16, ilpop17, ilpop18, ilpop19]

# %%
wellpathpop = [wpop09, wpop10, wpop11, wpop12, wpop13, wpop14, wpop15, wpop16, wpop17, wpop18, wpop19]
wellpathpop
# Out:
# [3479.0,
#  3956.0,
#  3633.0,
#  3973,
#  3832.0,
#  3682.0,
#  4534.0,
#  4447.0,
#  4756.0,
#  4835.5,
#  4856.8]

# %%
wellpathdeathpop = [wd09, wd10, wd11, wd12, wd13, wd14, wd15, wd16, wd17, wd18, wd19]
wellpathdeathpop
# Out:
# [2, 5, 4, 6, 2, 3, 8, 2, 9, 14, 5]

# %%
publicpop = [ppop09, ppop10, ppop11, ppop12, ppop13, ppop14, ppop15, ppop16, ppop17, ppop18, ppop19]
publicpop
# Out:
# [2316.0,
#  2322.0,
#  2172.0,
#  2303,
#  2445.0,
#  1979.0,
#  1863.0,
#  1913.0,
#  1185.0,
#  1210.0,
#  1202.0]

# %%
publicdeathpop = [pd09, pd10, pd11, pd12, pd13, pd14, pd15, pd16, pd17, pd18, pd19]
publicdeathpop
# Out:
# [2, 4, 3, 1, 1, 3, 2, 2, 2, 2, 1]

# %%
newpop = pd.DataFrame(totalpop, index =[year], columns = ["population"])
newpop["wellpath population"] = wellpathpop
newpop["public population"] = publicpop
newpop["non wellpath population"] = newpop["population"] - newpop["wellpath population"]
newpop["deaths"] = totaldeaths
newpop["wellpath deaths"] = wellpathdeathpop
newpop["public deaths"] = publicdeathpop
newpop["non wellpath deaths"] = newpop["deaths"] - newpop["wellpath deaths"]
newpop["deathrate"] = (newpop["deaths"]/newpop["population"])*1000
newpop["wellpath deathrate"] = (newpop["wellpath deaths"]/newpop["public population"])*1000
newpop["public deathrate"] = (newpop["public deaths"]/newpop["wellpath population"])*1000
newpop["non wellpath deathrate"] = (newpop["non wellpath deaths"]/newpop["non wellpath population"])*1000
newpop
# Out:
#       population  wellpath population  public population  \
# 2009     8465.50               3479.0             2316.0
# 2010     8142.40               3956.0             2322.0
# 2011     7640.50               3633.0             2172.0
# 2012     8132.00               3973.0             2303.0
# 2013     8144.25               3832.0             2445.0
# 2014     8069.98               3682.0             1979.0
# 2015     7357.75               4534.0             1863.0
# 2016     7319.86               4447.0             1913.0
# 2017     7743.53               4756.0             1185.0
# 2018     7838.90               4835.5             1210.0
# 2019     7920.48               4856.8             1202.0
#
#       non wellpath population  deaths  wellpath deaths  public deaths  \
# 2009                  4986.50       7                2              2
# 2010                  4186.40      11                5              4
# ...

# %%
## overall deathrate per 1000
newpop["deathrate"].sum()/11
# Out:
# 1.2512613710977165

# %%
## wellpath deathrate per 1000
newpop["wellpath deathrate"].sum()/11
# Out:
# 1.2561782606632

# %%
## non wellpath deathrate per 1000
newpop["non wellpath deathrate"].sum()/11
# Out:
# 1.2220657437522422

# %%
## public deathrate per 1000
newpop["public deathrate"].sum()/11
# Out:
# 0.5154615384882493

# %%
## overall deathrate per 1000 since 2015
newpop.loc[[2015, 2016, 2017, 2018, 2019], ["deathrate"]].sum()/5
# Out:
# deathrate    1.563815
# dtype: float64

# %%
## overall deathrate per 1000 before 2015

newpop.loc[[2009, 2010, 2011, 2012, 2013], ["deathrate"]].sum()/5
# Out:
# deathrate    0.990694
# dtype: float64

# %%
## wellpath deathrate per 1000 since 2015
newpop.loc[[2015, 2016, 2017, 2018, 2019], ["wellpath deathrate"]].sum()/5
# Out:
# wellpath deathrate    1.606255
# dtype: float64

# %%
## wellpath deathrate per 1000 before 2015
newpop.loc[[2009, 2010, 2011, 2012, 2013], ["wellpath deathrate"]].sum()/5
# Out:
# wellpath deathrate    0.994383
# dtype: float64

# %%
## non wellpath deathrate per 1000 since 2015
newpop.loc[[2015, 2016, 2017, 2018, 2019], ["non wellpath deathrate"]].sum()/5
# Out:
# non wellpath deathrate    1.488618
# dtype: float64

# %%
## non wellpath deathrate per 1000 before 2015
newpop.loc[[2009, 2010, 2011, 2012, 2013], ["non wellpath deathrate"]].sum()/5
# Out:
# non wellpath deathrate    0.972032
# dtype: float64

# %%
## public deathrate per 1000 since 2015
newpop.loc[[2015, 2016, 2017, 2018, 2019], ["public deathrate"]].sum()/5
# Out:
# public deathrate    0.386176
# dtype: float64

# %%
## public deathrate per 1000 before 2015
newpop.loc[[2009, 2010, 2011, 2012, 2013], ["public deathrate"]].sum()/5
# Out:
# public deathrate    0.584885
# dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-124-111f00e1c2c8> in <module>
# ----> 1 filter1
#
# NameError: name 'filter1' is not defined
